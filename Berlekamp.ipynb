# %%
from algebra_computacional.factories import *
from algebra_computacional.parsers import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-cf62e17e7c0a> in <module>()
# ----> 1 from algebra_computacional.factories import *
#       2 from algebra_computacional.parsers import *
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\factories\__init__.py in <module>()
#       1 #from .FractionFactory import *
# ----> 2 from .factories import *
#       3
#       4 Z_X = PolynomialFactory(IntegerFactory())
#       5
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\factories\factories.py in <module>()
# ----> 1 from algebra_computacional.rings import (Integer,
#       2                                          PolynomialOverIntegral,
#       3                                          PolynomialOverField,
#       4                                          PolynomialOverGalois,
#       5                                          QuotientElement,
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\__init__.py in <module>()
# ----> 1 from .rings import *
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in <module>()
#       9                                              )
#      10 from algebra_computacional.utilities.haskell import zipWithAll, concat, eea, foldl
# ---> 11 from algebra_computacional.factories import GaloisPolynomialFactory
#      12 import math
#      13 import fractions
#
# ImportError: cannot import name GaloisPolynomialFactory

# %%
GF9_X = GaloisPolynomialFactory(3,'a^2 - a - 1','x')
a = GF9_X('x^3 + x^2 + x - a')

# %%
SQFREE_a = a.squarefree()
for x in SQFREE_a:
    print str(x)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9ddb5dbf7360> in <module>()
# ----> 1 SQFREE_a = a.squarefree()
#       2 for x in SQFREE_a:
#       3     print str(x)
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in squarefree(self)
#     260         while not w[-1].is_one():
#     261             w.append(g[-1].gcd(w[-1]))
# --> 262             g.append(g[-1]/w[-1])
#     263             L.append(w[-2]/w[-1])
#     264         if g[-1].is_one():
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __div__(self, rop)
#     202         return q, r
#     203     def __div__(self, rop):
# --> 204         return divmod(self, rop)[0]
#     205     def __mod__(self, rop):
#     206         return divmod(self, rop)[1]
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __divmod__(self, rop)
#     221         r = self
#     222         while not r.is_zero() and r.degree() >= rop.degree():
# --> 223             t = self.factory.monomial(r.degree() - rop.degree(), r.leading_coefficient() * rop.leading_coefficient().inverse())
#     224             q = q+t
#     225             r = r - (t*rop)
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in inverse(self)
#      62         return self.factory(self.value * op2.value)
#      63     def inverse(self):
# ---> 64         g, u, v = self.value.eea(self.factory.quotient_factor)
#      65         if not g.is_one():
#      66             u = -u
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\structures\structures.pyc in eea(self, b)
#      58         while not R[i].is_zero():
#      59             Q = R[i-1] / R[i]
# ---> 60             R.append(R[i-1] - Q*R[i])
#      61             S.append(S[i-1] - Q*S[i])
#      62             T.append(T[i-1] - Q*T[i])
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __mul__(self, rop)
#     122         a = self.factory.zero()
#     123         for k in self.coefficients.iterkeys():
# --> 124             a = a + self.factory({ j+k: self.coefficients[k]*rop.coefficients[j] for j in rop.coefficients.iterkeys() })
#     125         return a
#     126     def __neg__(self):
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __add__(self, rop)
#     116         self.factory = builder
#     117     def __add__(self, rop):
# --> 118         return self.factory({k: self.coefficients.get(k, self.factory.inner_factory.zero()) + rop.coefficients.get(k, self.factory.inner_factory.zero()) for k in set(self.coefficients) | set(rop.coefficients)})
#     119     def __sub__(self, rop):
#     120         return self.factory({k: self.coefficients.get(k, self.factory.inner_factory.zero()) - rop.coefficients.get(k, self.factory.inner_factory.zero()) for k in set(self.coefficients) | set(rop.coefficients)})
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\factories\factories.pyc in __call__(self, expression)
#      71             if not coefficients:
#      72                 return self.zero()
# ---> 73             return self.product(coefficients, self)
#      74         else:
#      75             raise TypeError('Expression should be string or dictionary.')
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __init__(self, coefficients, builder)
#     212 class PolynomialOverGalois(PolynomialOverField, Field):
#     213     def __init__(self, coefficients, builder):
# --> 214         super(PolynomialOverGalois, self).__init__(coefficients, builder)
#     215     def inverse(self):
#     216         return self.factory.one() / self
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __init__(self, coefficients, builder)
#     190     """docstring for Polynomial"""
#     191     def __init__(self, coefficients, builder):
# --> 192         super(PolynomialOverField, self).__init__(coefficients, builder)
#     193     def __divmod__(self, rop):
#     194         if rop.is_zero():
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\rings\rings.py in __init__(self, coefficients, builder)
#     112     """docstring for Polynomial"""
#     113     def __init__(self, coefficients, builder):
# --> 114         super(PolynomialOverIntegral, self).__init__()
#     115         self.coefficients = coefficients
#     116         self.factory = builder
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\structures\structures.pyc in __init__(self)
#      81 class Field(EuclideanDomain):
#      82     def __init__(self):
# ---> 83         super(Field, self).__init__()
#      84
#      85 class GaloisField(Field):
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\structures\structures.pyc in __init__(self)
#      50     """docstring for Euclid"""
#      51     def __init__(self):
# ---> 52         super(EuclideanDomain, self).__init__()
#      53     def eea(self, b):
#      54         R = [self, b]
#
# F:\Documents\Projects\Algebra-Computacional-UCM\algebra_computacional\structures\structures.pyc in __init__(self)
#       8     """docstring for Integral"""
#       9     def __init__(self):
# ---> 10         super(Integral, self).__init__()
#      11         self.factory = None
#      12     def builder(self):
#
# KeyboardInterrupt:

# %%
DISTINCT_a = a.distinctdegree()
for x in DISTINCT_a:
    print str(x[0]), 'of degree', x[1]

# %%
a.berlekamp_splitting([])

# %%
Integers = IntegerFactory()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fbf5d4b6dfce> in <module>()
# ----> 1 Integers = IntegerFactory()
#
# NameError: name 'IntegerFactory' is not defined
